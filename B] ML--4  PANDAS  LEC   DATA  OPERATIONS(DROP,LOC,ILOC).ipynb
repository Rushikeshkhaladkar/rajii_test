# %%
import pandas as pd

# %%
obj = pd.read_csv("sample.csv")

# %%
obj
# Out:
#     id   name    city            email   age
# 0  1.0  rushi    pune    abc@gmail.com  23.0
# 1  2.0   rush   pune2   rush@gmail.com  25.0
# 2  1.0  rushi    pune    abc@gmail.com  23.0
# 3  4.0  rajii  mumbai  rajii@gmail.com  25.0
# 4  5.0   GURU     NaN     su@gmail.com   NaN
# 5  NaN    NaN     NaN              NaN   NaN
# 6  NaN    NaN     NaN               67   NaN
# 7  4.0  rajii  mumbai  rajii@gmail.com  25.0
# 8  1.0  rushi    pune    abc@gmail.com  23.0
# 9  1.0  rushi    pune    abc@gmail.com  23.0

# %% [markdown]
# ### remove duplicate rows

# %%
obj.drop_duplicates(inplace=True)

# %%
obj
# Out:
#     id   name    city            email   age
# 0  1.0  rushi    pune    abc@gmail.com  23.0
# 1  2.0   rush   pune2   rush@gmail.com  25.0
# 3  4.0  rajii  mumbai  rajii@gmail.com  25.0
# 4  5.0   GURU     NaN     su@gmail.com   NaN
# 5  NaN    NaN     NaN              NaN   NaN
# 6  NaN    NaN     NaN               67   NaN

# %%
obj.dtypes
# Out:
# id       float64
# name      object
# city      object
# email     object
# age      float64
# dtype: object

# %%
obj1 = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\pandas\benguluru_house_data.csv")

# %%
obj1
# Out:
#                   area_type   availability                  location  \
# 0                       NaN            NaN                       NaN
# 1      Super built-up  Area         19-Dec  Electronic City Phase II
# 2                       NaN            NaN                       NaN
# 3                Plot  Area  Ready To Move          Chikka Tirupathi
# 4                       NaN            NaN                       NaN
# ...                     ...            ...                       ...
# 26635        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 26636                   NaN            NaN                       NaN
# 26637  Super built-up  Area         18-Jun           Padmanabhanagar
# 26638                   NaN            NaN                       NaN
# 26639  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0            NaN      NaN        NaN   NaN      NaN     NaN
# ...

# %%
obj1.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %% [markdown]
# ### change data type of colums

# %%
obj1['total_sqft'].unique()
# Out:
# array([nan, '1056', '2600', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
obj1.dropna()
# Out:
#                   area_type   availability                  location  \
# 1      Super built-up  Area         19-Dec  Electronic City Phase II
# 3                Plot  Area  Ready To Move          Chikka Tirupathi
# 7      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 11     Super built-up  Area  Ready To Move                Whitefield
# 23               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 26627  Super built-up  Area  Ready To Move               Uttarahalli
# 26629  Super built-up  Area  Ready To Move         Green Glen Layout
# 26631        Built-up  Area  Ready To Move                Whitefield
# 26635        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 26637  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 1          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
obj1['price'].unique()
# Out:
# array([   nan,  39.07, 120.  , ...,  40.14, 231.  , 488.  ])

# %%
obj1.dropna(inplace=True)

# %%
obj1['price'] = obj1['price'].astype('int')

# %%
obj1
# Out:
#                   area_type   availability                  location  \
# 1      Super built-up  Area         19-Dec  Electronic City Phase II
# 3                Plot  Area  Ready To Move          Chikka Tirupathi
# 7      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 11     Super built-up  Area  Ready To Move                Whitefield
# 23               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 26627  Super built-up  Area  Ready To Move               Uttarahalli
# 26629  Super built-up  Area  Ready To Move         Green Glen Layout
# 26631        Built-up  Area  Ready To Move                Whitefield
# 26635        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 26637  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony  price
# 1          2 BHK  Coomee        1056   2.0      1.0     39
# ...

# %%
r = pd.read_csv("sample.csv")

# %%
r
# Out:
#     id   name    city            email   age
# 0  1.0  rushi    pune    abc@gmail.com  23.0
# 1  2.0   rush   pune2   rush@gmail.com  25.0
# 2  1.0  rushi    pune    abc@gmail.com  23.0
# 3  4.0  rajii  mumbai  rajii@gmail.com  25.0
# 4  5.0   GURU     NaN     su@gmail.com   NaN
# 5  NaN    NaN     NaN              NaN   NaN
# 6  NaN    NaN     NaN               67   NaN
# 7  4.0  rajii  mumbai  rajii@gmail.com  25.0
# 8  1.0  rushi    pune    abc@gmail.com  23.0
# 9  1.0  rushi    pune    abc@gmail.com  23.0

# %%
r.dropna(inplace=True)

# %%
r.dtypes
# Out:
# id       float64
# name      object
# city      object
# email     object
# age      float64
# dtype: object

# %%
r['age'] = r['age'].astype('int')

# %%
r
# Out:
#     id   name    city            email  age
# 0  1.0  rushi    pune    abc@gmail.com   23
# 1  2.0   rush   pune2   rush@gmail.com   25
# 2  1.0  rushi    pune    abc@gmail.com   23
# 3  4.0  rajii  mumbai  rajii@gmail.com   25
# 7  4.0  rajii  mumbai  rajii@gmail.com   25
# 8  1.0  rushi    pune    abc@gmail.com   23
# 9  1.0  rushi    pune    abc@gmail.com   23

# %%
obj1['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1521', ..., '1919', '2111', '4689'], dtype=object)
